# %% [markdown]
# ## imports

# %%
from delta.tables import DeltaTable
from pyspark.sql.functions import *

# %% [markdown]
# ## path

# %%
# %run ./00_setup
# Out:
# ## paths

# %% [markdown]
# ## vacuum  silver dataset

# %%
DeltaTable.forPath(spark, silver_write_path).vacuum(168)
