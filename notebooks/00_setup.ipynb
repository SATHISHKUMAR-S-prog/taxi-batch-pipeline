# %% [markdown]
# ## paths

# %%
raw_input_path = "/Volumes/workspace/sathish/trip/input/"
bronze_write_path = "/Volumes/workspace/sathish/trip/bronze/"
silver_write_path = "/Volumes/workspace/sathish/trip/silver/"
gold_write_path = "/Volumes/workspace/sathish/trip/gold/"
